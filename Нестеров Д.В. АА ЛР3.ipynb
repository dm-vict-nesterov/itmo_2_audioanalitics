# %%
import librosa
from librosa.feature import melspectrogram
from librosa.core import load
from librosa.display import specshow

# %%
import pandas as pd
import librosa
from librosa.feature import melspectrogram
from librosa.core import load
from librosa.display import specshow
from librosa import power_to_db

import matplotlib.pyplot as plt

# %%
train_labels=pd.read_csv(r"extracted.csv")

# %%
import os
from tqdm import tqdm
import pickle
import pandas as pd
import numpy as np

from librosa.feature import melspectrogram
from librosa.core import load as load_wav
from librosa import power_to_db


def extract_log_mel_feats(set_type, path_to_csv, path_to_files, out_path, sr, fft_size, hop, n_mels):
    """
    Extract features from given files and store them in binary format.

    :param set_type:
    :param path_to_csv: path to loaded csv
    :param path_to_files: path to loaded data
    :param out_path: path to store extracted features
    :param sr: input files sample rate
    :param fft_size: size of fft window
    :param hop: hop size
    :param n_mels: number of mel band

    :return:

    """
    set_type = set_type.lower()
    if set_type not in ['train', 'test']:
        raise Exception('Such set type not supported: {}'.format(set_type))

    feats = []

    if set_type == 'train':
        meta = pd.read_csv(path_to_csv, skiprows=1, names=['fname', 'label', 'manually_verified'])

        file_names = list(meta['fname'])
        n_files = len(file_names)
        labels = list(meta['label'])

        uniq_labels = np.sort(np.unique(labels))
        label_to_id = {label: i for i, label in enumerate(uniq_labels)}

        print('Total files:', n_files)

        for i, (file_name, label) in tqdm(enumerate(zip(file_names, labels))):
            wav_data, sr = load_wav(os.path.join(path_to_files, file_name), sr=sr)
            mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
            log_mel_spec = power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
                'label_id': label_to_id[label]
            })
        pickle.dump(feats, open(out_path, 'wb'))    
        return label_to_id
    else:
        for i, file_name in tqdm(enumerate(os.listdir(path_to_files))):
            wav_data, sr = load_wav(os.path.join(path_to_files, file_name), sr=sr)
            if len(wav_data) == 0:
                # print('Empty file:', file_name)
                wav_data = np.zeros(sr)
            mel_spec = melspectrogram(wav_data, n_fft=fft_size, n_mels=n_mels, fmax=sr // 2)
            log_mel_spec = power_to_db(mel_spec, ref=np.max)
            feats.append({
                'fname': file_name,
                'feature': log_mel_spec,
            })

    pickle.dump(feats, open(out_path, 'wb'))

# %% [markdown]
# Меняем ЧД с 11056 на 8кГц

# %%
train_folder = r'C:\Users\nesterov-dv\Downloads\audio_train\train'


sample_rate = 8000
fft_size = 1024
overlap = 4
hop = fft_size // overlap
mels = 64

# %%
wav_data, sr = load(os.path.join(r"C:\itmo\aa\lr03\audio_train\train", "0b9b49bea8fff279a2d3.wav"), sr=sample_rate)
mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=mels, 
                          fmax=sample_rate//2)

plt.figure(figsize=(10, 4))
colors = 'viridis'
specshow(mel_spec, y_axis='mel', fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Мелспектрограмма')
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 4))
specshow(power_to_db(mel_spec, ref=np.max), y_axis='mel',
         fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Логарифм мелспектрограммы')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/3300481726.py:2: FutureWarning: Pass y=[-4.6377856e-04 -1.0577029e-03 -9.8962605e-04 ...  9.2306305e-05
#   1.9873465e-04  3.2826100e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=mels,

# %%
np.shape(mel_spec)
# Out:
# (64, 108)

# %%
path_to_csv = os.path.join(r'C:\Users\nesterov-dv\Downloads', 'train.csv')

pickle_train_path = os.path.join('train.pickle')
# pickle_test_path = os.path.join('./data', 'test.pickle')

label_to_id = extract_log_mel_feats('train', path_to_csv, train_folder, pickle_train_path, sample_rate, fft_size, hop, mels)
id_to_label = [label for label, i in label_to_id.items()]

# extract_log_mel_feats('test', '', test_folder, pickle_test_path, sample_rate, fft_size, hop, mels)
# Out:
# Total files: 5683
# 0it [00:00, ?it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[2.73328507e-04 1.12545575e-04 7.36307629e-05 ... 3.66125023e-04
#  5.07207529e-04 4.69101506e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00041357 0.00062161 0.00042219 ... 0.00044735 0.00034906 0.00033016] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 2it [00:00,  4.56it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.0011643  0.00206978 0.00171296 ... 0.00025734 0.00040175 0.00037633] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 3it [00:00,  3.77it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00061024 0.00222693 0.0004123  ... 0.01867408 0.0132568  0.00618902] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 4it [00:00,  4.03it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-0.00244289 -0.00219879  0.00274328 ...  0.00019967  0.00018066
#   0.00031356] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[6.6923611e-05 1.9675758e-04 2.1897981e-04 ... 4.1189985e-04 4.0771085e-04
#  1.6775340e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 6it [00:01,  5.45it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-0.0007386  -0.0015318  -0.00120243 ...  0.0002984   0.00029818
#   0.00031319] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 7it [00:01,  4.43it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-1.4965952e-05  2.0210234e-04  3.3897042e-04 ...  2.5430872e-04
#   3.1250212e-04  5.1621487e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00231618 0.00128894 0.00329243 ... 0.00041933 0.00039238 0.00033663] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 9it [00:01,  5.65it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[1.9218423e-04 3.9659353e-04 5.0303595e-05 ... 2.8900988e-04 1.4434879e-04
#  3.0822912e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00037468 0.00034165 0.00016194 ... 0.00048317 0.0002981  0.00017482] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 11it [00:01,  7.77it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-4.2927694e-02 -2.7902143e-02  3.1334106e-02 ...  1.9139328e-04
#   9.8275668e-05  4.0648629e-05] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00024974 0.00031103 0.00036867 ... 0.0001475  0.00011127 0.00034349] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 13it [00:02,  8.61it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[1.4311539e-04 2.5224825e-04 1.3843403e-04 ... 4.6394629e-04 7.0705013e-05
#  2.6664845e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00048675 0.00094617 0.00059421 ... 0.00046693 0.0003922  0.0003859 ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 15it [00:02,  5.56it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[1.8385367e-04 4.3638301e-04 3.5463070e-04 ... 5.9728129e-05 2.9742246e-04
#  3.0519982e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[2.5082129e-01 5.2554047e-01 4.7717953e-01 ... 3.3038031e-04 2.9366769e-04
#  4.5408655e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00036103 0.00041665 0.00019144 ... 0.00020371 0.00015263 0.00021579] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 18it [00:02,  8.09it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-0.00036387 -0.00071532  0.00010451 ...  0.00038169  0.00018752
#   0.00050883] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00014308 0.00012179 0.00030748 ... 0.0004412  0.00023986 0.00039091] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 20it [00:03,  8.96it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[
/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-0.00032755  0.0082176  -0.00269555 ...  0.00026258  0.00034153
#   0.00019558] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[ 0.00049021  0.00069347 -0.0002721  ...  0.00039691  0.00031514
#   0.00030431] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-0.00316142 -0.0068657  -0.00990438 ...  0.00020223  0.0001521
#   0.00040878] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 5679it [11:30, 12.70it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[ 0.03759558 -0.00933592 -0.00367949 ...  0.00031408  0.00019603
#   0.00019629] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00031248 0.00051609 0.00060385 ... 0.00024675 0.00019498 0.00015082] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 5681it [11:30, 10.05it/s]C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[-2.4361269e-01 -7.4056405e-01 -8.7386596e-01 ...  1.5550302e-05
#   2.7939101e-04  2.0404297e-04] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# C:\Users\nesterov-dv\AppData\Local\Temp/ipykernel_12352/1071006633.py:48: FutureWarning: Pass y=[0.00089386 0.00200127 0.00077102 ... 0.00050891 0.00044269 0.00045997] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spec = melspectrogram(wav_data, n_fft=fft_size, hop_length=hop, n_mels=n_mels, fmax=sr // 2)
# 5683it [11:30,  8.23it/s]

# %% [markdown]
# Добавлен слой self.fc2 = nn.Linear(1000, 41)

# %%
import numpy as np
import pandas as pd
import soundfile as sf
import torch.nn.functional as F
import torch.nn as nn
import torch


class DummyNetwork(nn.Module):
    def __init__(self):
        super(DummyNetwork, self).__init__()
        
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=64, kernel_size=5, stride=(2, 2))
        self.conv2 = nn.Conv2d(in_channels=64, out_channels=96, kernel_size=3, stride=(1, 1))
        self.conv3 = nn.Conv2d(in_channels=96, out_channels=64, kernel_size=3, stride=(1, 1))
        
        self.mp = nn.MaxPool2d(kernel_size=(2, 2), stride=(1, 1))
        
        self.dropout1 = nn.Dropout(p=0.3)
        self.dropout2 = nn.Dropout(p=0.3)
        self.dropout3 = nn.Dropout(p=0.3)
        
        self.bn1 = nn.BatchNorm2d(num_features=64)
        self.bn2 = nn.BatchNorm2d(num_features=96)
        self.bn3 = nn.BatchNorm2d(num_features=64)
        
        self.flat = nn.Flatten()
        
        # 33856 - должно соответствовать форме self.flat
        self.fc1 = nn.Linear(33856, 1000)
        self.fc2 = nn.Linear(1000, 41)

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout1(x)
        
        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout2(x)
        
        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = self.mp(x)
        x = self.dropout3(x)
        
        x = self.flat(x)
        # здесь можно еще добавить полносвязных слой или слои
        x = self.fc1(x)
        x = self.fc2(x)
        return x

# %%
random_input = torch.randn(1, 1, 64, 64, requires_grad=True)
network = DummyNetwork()
output = network(random_input)
print(output)
# Out:
# tensor([[ 1.1522,  0.2939, -0.0127,  0.0584,  0.0220,  0.7059, -0.1700, -0.1854,
#          -0.1288,  0.5193,  0.3972,  0.7349, -0.6791,  0.0125, -0.3519,  0.1318,
#           0.4858,  0.0644, -0.7375, -0.6785,  0.2299, -0.0516,  0.3012,  0.1585,
#           0.7145, -0.4747,  0.1389, -0.2103, -0.1452, -0.5299, -0.3608,  0.5584,
#           0.4728, -0.4246,  0.5017, -0.0280,  0.5040, -0.3700, -0.3481, -0.1226,
#           0.0312]], grad_fn=<AddmmBackward0>)

# %%
import torch.optim as optim


criterion = nn.CrossEntropyLoss()

optimizer = optim.Adam(network.parameters(), lr=0.001)
optimizer.zero_grad()

random_input = torch.randn(3, 1, 64, 64, requires_grad=True)

output = network(random_input)
target = torch.empty(3, dtype=torch.long).random_(5)

loss = criterion(output, target)

print(loss.item())

loss.backward()
optimizer.step()
# Out:
# 3.4765121936798096

# %%
import pickle

pickle_train_data = pickle.load(open(pickle_train_path, 'rb'))

# %%
def prepare_shape(feature):
    tmp = feature
    N = 64 # размер во времени (можно увеличить, должно стать лучше)
    while tmp.shape[1] < N:
        # можно попробовать сделать np.pad для коротких файлов, вместо повторения до необходимой длины
        tmp = np.hstack((tmp, tmp))
    # случайный сдвиг должен улучшить результат (для этого нужно функцию перенести в EventDetectionDataset)
    tmp = tmp[np.newaxis, :, :N]
    return tmp

# %%
# можно улучшить, используя сбалансированное валидационное множество
# гуглить stratified train test split sklearn
validation_set_size = 800

x_val = []
y_val = []

x_tr = []
y_tr = []

for i, row in enumerate(pickle_train_data):
    feature = prepare_shape(row['feature'])
    if i < validation_set_size:
        x_val.append(feature)
        y_val.append(row['label_id'])
    else:
        x_tr.append(feature)
        y_tr.append(row['label_id'])
x_val = np.asarray(x_val)
x_tr = np.asarray(x_tr)

y_val = np.asarray(y_val)
y_tr = np.asarray(y_tr)

# %%
np.shape(row['feature'])
# Out:
# (64, 211)

# %%
from torch.utils.data import Dataset


class EventDetectionDataset(Dataset):
    def __init__(self, x, y=None):
        self.x = x
        self.y = y
    
    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        # добавить сюда prepare_shape()
        if self.y is not None:
            return self.x[idx], self.y[idx]
        return self.x[idx]

# %%
train_dset = EventDetectionDataset(x_tr, y_tr)
val_dset = EventDetectionDataset(x_val, y_val)

# %%
sample_x, sample_y = val_dset[2]
print(sample_y)
# print(id_to_label[sample_y])
plt.figure(figsize=(10, 4))
colors = 'viridis'
specshow(sample_x[0], y_axis='mel', fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Мелспектрограмма')
plt.tight_layout()
plt.show()
# Out:
# 14

# %%
sample_x, sample_y = val_dset[2]
print(sample_y)
# print(id_to_label[sample_y])
plt.figure(figsize=(10, 4))
colors = 'viridis'
specshow(sample_x[0], y_axis='mel', fmax=sample_rate//2, x_axis='time', cmap=colors)
plt.colorbar(format='%+2.0f дБ')
plt.title('Мелспектрограмма')
plt.tight_layout()
plt.show()
# Out:
# 14

# %%
from torch.utils.data import DataLoader

train_loader = DataLoader(train_dset, batch_size=40, shuffle=True, num_workers=0)
val_loader = DataLoader(val_dset, batch_size=40, shuffle=False, num_workers=0)

# %%
from sklearn.metrics import accuracy_score

# %% [markdown]
# Используем optimizer Adam вместо SGD

# %%
n_epoch = 50
criterion = nn.CrossEntropyLoss()
network = DummyNetwork()

optimizer = optim.Adam(network.parameters(), lr=0.001)

# %%
train_loss = []
val_loss = []

train_acc = []
val_acc = []

for e in range(n_epoch):
    print('epoch #', e)
    # train
    loss_list = []
    outputs = []
    targets = []
    for i_batch, sample_batched in enumerate(train_loader):
        x, y = sample_batched
        optimizer.zero_grad()

        output = network(x)
        outputs.append(output.detach().numpy().argmax(axis=1))
    
        target = y
        targets.append(target)
        
        loss = criterion(output, target.long())
        loss_list.append(loss.item())
        loss.backward()
        optimizer.step()
    y_true = np.hstack(targets)
    y_pred = np.hstack(outputs)
    acc = accuracy_score(y_true, y_pred)
    train_loss.append(np.mean(loss_list))
    train_acc.append(acc)
    print('mean train loss:', train_loss[-1])
    print('train accuracy:', acc)
    
    
    loss_list = []
    outputs = []
    targets = []
    with torch.no_grad():
        for i_batch, sample_batched in enumerate(val_loader):
            x, y = sample_batched
#             optimizer.zero_grad()

            output = network(x)
            outputs.append(output.detach().numpy().argmax(axis=1))

            target = y
            targets.append(target)

            loss = criterion(output, target.long())
            loss_list.append(loss.item())
#             loss.backward()
#             optimizer.step()
            
        y_true = np.hstack(targets)
        y_pred = np.hstack(outputs)
        acc = accuracy_score(y_true, y_pred)
        val_loss.append(np.mean(loss_list))
        val_acc.append(acc)
        print('mean val loss:', val_loss[-1])
        print('val accuracy:', acc)
# Out:
# epoch # 0
# mean train loss: 30.208772771726778
# train accuracy: 0.10403440507884497
# mean val loss: 11.227954244613647
# val accuracy: 0.125
# epoch # 1
# mean train loss: 7.938027560226316
# train accuracy: 0.1716158099528978
# mean val loss: 5.869643330574036
# val accuracy: 0.15375
# epoch # 2
# mean train loss: 5.25112362218097
# train accuracy: 0.20970714724554576
# mean val loss: 4.833273530006409
# val accuracy: 0.20375
# epoch # 3
# mean train loss: 3.6692942933338446
# train accuracy: 0.26356747900880606
# mean val loss: 4.185560011863709
# val accuracy: 0.2175
# epoch # 4
# mean train loss: 3.1967156999479465
# train accuracy: 0.28527544542289573
# mean val loss: 3.449196088314056
# val accuracy: 0.215
# epoch # 5
# mean train loss: 2.7280737258554475
# train accuracy: 0.33155846815482287
# mean val loss: 2.747646355628967
# val accuracy: 0.30625
# epoch # 6
# mean train loss: 2.367983812481407
# train accuracy: 0.386852344869957
# mean val loss: 2.8778853535652162
# val accuracy: 0.30625
# epoch # 7
# mean train loss: 2.228035464034817
# train accuracy: 0.4112226090518124
# mean val loss: 2.6021486937999727
# val accuracy: 0.33125
# epoch # 8
# mean train loss: 2.1264979093055416
# train accuracy: 0.43354495187384806
# mean val loss: 2.3973061740398407
# val accuracy: 0.3825
# epoch # 9
# mean train loss: 2.141337976223085
# train accuracy: 0.43600245750563177
# mean val loss: 2.4749846339225767
# val accuracy: 0.3575
# epoch # 10
# mean train loss: 2.012464669661793
# train accuracy: 0.46405898013516284
# mean val loss: 2.3143459141254423
# val accuracy: 0.4
# epoch # 11
# mean train loss: 1.8601888970630924
# train accuracy: 0.4915011263567479
# mean val loss: 2.323744612932205
# val accuracy: 0.425
# epoch # 12
# mean train loss: 1.7839828865314886
# train accuracy: 0.7503583862379685
# mean val loss: 2.63882572054863
# val accuracy: 0.495
# epoch # 34
# mean train loss: 0.5190992699406012
# train accuracy: 0.8472250665574442
# mean val loss: 2.781722730398178
# val accuracy: 0.495
# epoch # 35
# mean train loss: 0.3562905661822335
# train accuracy: 0.8945320499692812
# mean val loss: 3.3512696444988253
# val accuracy: 0.47875
# epoch # 36
# mean train loss: 0.5630179624247357
# train accuracy: 0.868113864427606
# mean val loss: 4.147233068943024
# val accuracy: 0.41875
# epoch # 37
# mean train loss: 1.4060476516805045
# train accuracy: 0.6743805037886546
# mean val loss: 2.9626842021942137
# val accuracy: 0.41625
# epoch # 38
# mean train loss: 1.0815852936205825
# train accuracy: 0.7524063075977883
# mean val loss: 2.8535387575626374
# val accuracy: 0.4375
# epoch # 39
# mean train loss: 1.1628744839652767
# train accuracy: 0.7186156051607618
# mean val loss: 2.7367040038108827
# val accuracy: 0.4775
# epoch # 40
# mean train loss: 0.7432017769755387
# train accuracy: 0.7988941224656974
# mean val loss: 3.0542531609535217
# val accuracy: 0.47
# epoch # 41
# mean train loss: 0.5734481084637526
# train accuracy: 0.8623796846201106
# mean val loss: 3.4797876834869386
# val accuracy: 0.46
# epoch # 42
# mean train loss: 0.9590183603085154
# train accuracy: 0.7716567683800942
# mean val loss: 3.107033610343933
# val accuracy: 0.445
# epoch # 43
# mean train loss: 0.7967018342720784
# train accuracy: 0.79193118984231
# mean val loss: 2.952882927656174
# val accuracy: 0.46875
# epoch # 44
# mean train loss: 0.41658218332180164
# train accuracy: 0.8890026622977678
# mean val loss: 3.1852638483047486
# val accuracy: 0.475
# epoch # 45
# mean train loss: 0.5110309136713423
# train accuracy: 0.859103010444399
# mean val loss: 3.473941922187805
# val accuracy: 0.475
# epoch # 46
# mean train loss: 0.518268059242547
# train accuracy: 0.8613557239402007
# mean val loss: 3.6884876489639282
# val accuracy: 0.43375
# epoch # 47
# mean train loss: 0.5166280005520921
# train accuracy: 0.8648371902518943
# mean val loss: 3.371056020259857
# val accuracy: 0.4575
# epoch # 48
# mean train loss: 0.41678090629781167
# train accuracy: 0.9002662297767766
# mean val loss: 3.480930972099304
# val accuracy: 0.45625
# epoch # 49
# mean train loss: 0.3796778515405287
# train accuracy: 0.9043620724964161
# mean val loss: 3.9472289085388184
# val accuracy: 0.4775

# %%
epochs = np.arange(1, n_epoch+1)

axes = plt.gca()
axes.set_ylim([0,max(max(train_loss), max(val_loss))+1])
plt.plot(epochs, train_loss, 'r', label='train')
plt.plot(epochs, val_loss, 'b', label='val')
plt.title('loss')
plt.xlabel('epoch number')
plt.ylabel('loss value')
plt.legend()
plt.grid()
plt.show()


axes = plt.gca()
axes.set_ylim([0,1])
plt.plot(epochs, train_acc, 'r', label='train')
plt.plot(epochs, val_acc, 'b', label='val')
plt.title('accuracy')
plt.xlabel('epoch number')
plt.ylabel('accuracy value')
plt.legend()
plt.grid()
plt.show()
